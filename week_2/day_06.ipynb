# %% [markdown]
# # Day 6 — Tuples
#
# **How to use this notebook:**
# - Read each exercise, fill in your solution (replace `pass`)
# - Run the test cell right after to see **APPROVED** or **FAILED**
# - Do NOT modify the test cells
#
# **Key concept:** Tuples are like lists but **immutable** — once created, you cannot change their values directly.

# %% [markdown]
# ---
# ## Exercise 1 — Tuple Access
#
# Return a tuple containing four things about the input tuple:
#
# | Position | Description |
# |---|---|
# | 1st | first element |
# | 2nd | last element |
# | 3rd | length |
# | 4th | second-to-last element |
#
# **Hint:** Use positive and negative indexing.
#
# | Input | Expected Output |
# |---|---|
# | `tuple_access((10,20,30,40,50))` | `(10, 50, 5, 40)` |
# | `tuple_access(('a','b','c'))` | `('a', 'c', 3, 'b')` |

# %%
def tuple_access(t):
    return (t[0], t[-1], len(t), t[-2] )

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 1: tuple_access ──')
_check('(10,20,30,40,50)', tuple_access((10,20,30,40,50)), (10,50,5,40))
_check("('a','b','c')",    tuple_access(('a','b','c')),    ('a','c',3,'b'))
# Out:
# ── Exercise 1: tuple_access ──
#   ✔ APPROVED — (10,20,30,40,50)
#   ✔ APPROVED — ('a','b','c')

# %% [markdown]
# ---
# ## Exercise 2 — Coordinate Bounds
#
# `points` is a list of `(lat, lon)` tuples representing GPS coordinates.
#
# Return a dictionary with the extreme points:
#
# | Key | Meaning |
# |---|---|
# | `'north'` | highest latitude |
# | `'south'` | lowest latitude |
# | `'east'` | highest longitude |
# | `'west'` | lowest longitude |
#
# **Hint:** Use `max()` and `min()` with a `key` argument, or unpack with a loop.

# %%
def coordinate_bounds(points):
    lats = [p[0] for p in points]
    lons = [p[1] for p in points]
    return {

        "north": max(lats),
        "south": min(lats),
        "east": max(lons),
        "west": min(lons)

    }

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 2: coordinate_bounds ──')
_check('3 cities', coordinate_bounds([(40.7,-74.0),(51.5,-0.1),(35.7,139.7)]),
       {'north':51.5,'south':35.7,'east':139.7,'west':-74.0})
# Out:
# ── Exercise 2: coordinate_bounds ──
#   ✔ APPROVED — 3 cities

# %% [markdown]
# ---
# ## Mini-Project - Student Leaderboard
#
# You have a list of (name, score) tuples.
#
# Write a function that returns a dictionary with:
#
# | Key | Value |
# |---|---|
# | 'first' | name of highest scorer |
# | 'last' | name of lowest scorer |
# | 'average' | average score rounded to 2 decimals |
# | 'ranked' | list of names sorted highest to lowest score |

# %%
def leaderboard(students):
    name = [s[0] for s in students]
    score = [s[1] for s in students]

    f = score.index(max(score))
    l = score.index(min(score))
    a = round(sum(score) / len(score), 2)
    sorted_students = sorted([(s[1], s[0]) for s in students], reverse=True)
    r = [s[1] for s in sorted_students]

    return {
       
        "first": name[f],
        "last": name[l],
        "average": a,
        "ranked": r

    }

# %%
def _check(label, got, expected):
    if got == expected:
        print(f'  APPROVED - {label}')
    else:
        print(f'  FAILED   - {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n-- Mini-Project: leaderboard --')
r = leaderboard([('Alice',88),('Bob',95),('Eve',72)])
_check('first',   r.get('first'),   'Bob')
_check('last',    r.get('last'),    'Eve')
_check('average', r.get('average'), 85.0)
_check('ranked',  r.get('ranked'),  ['Bob','Alice','Eve'])
# Out:
# -- Mini-Project: leaderboard --
#   APPROVED - first
#   APPROVED - last
#   APPROVED - average
#   APPROVED - ranked
