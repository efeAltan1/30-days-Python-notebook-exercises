# %% [markdown]
# # Day 8 — Dictionaries
#
# **How to use this notebook:**
# - Read each exercise, fill in your solution (replace `pass`)
# - Run the test cell right after to see **APPROVED** or **FAILED**
# - Do NOT modify the test cells
#
# **Key concept:** Dictionaries store **key-value pairs**. They are mutable and allow fast lookup by key.

# %% [markdown]
# ---
# ## Exercise 1a — Add or Update
#
# Add a new student to the gradebook, or **update their grade** if they already exist.
#
# Return the updated gradebook.
#
# ```python
# gb = {}
# gb = add_or_update(gb, 'Alice', 92)  → {'Alice': 92}
# gb = add_or_update(gb, 'Bob', 78)    → {'Alice': 92, 'Bob': 78}
# gb = add_or_update(gb, 'Alice', 95)  → {'Alice': 95, 'Bob': 78}  # updated
# ```

# %%
def add_or_update(gradebook, name, grade):
    gradebook[name] = grade
    return gradebook

# %% [markdown]
# ---
# ## Exercise 1b — Delete Student
#
# Remove a student by name.
# - Return `(updated_gradebook, True)` if found and removed
# - Return `(original_gradebook, False)` if not found
#
# **Hint:** Use the `in` operator to check before deleting.

# %%
def delete_student(gradebook, name):
    
    if name in gradebook:
        del gradebook[name]
        return (gradebook, True)
    else:
        return (gradebook, False)

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 1: add_or_update / delete_student ──')
gb = {}
gb = add_or_update(gb, 'Alice', 92)
_check('add Alice',    gb, {'Alice': 92})
gb = add_or_update(gb, 'Bob', 78)
_check('add Bob',      gb, {'Alice': 92, 'Bob': 78})
gb = add_or_update(gb, 'Alice', 95)
_check('update Alice', gb, {'Alice': 95, 'Bob': 78})

gb2, ok = delete_student(dict(gb), 'Bob')
_check('delete Bob → dict',  gb2, {'Alice': 95})
_check('delete Bob → True',  ok,  True)
gb3, ok2 = delete_student(dict(gb), 'Eve')
_check('delete Eve → dict',  gb3, {'Alice': 95, 'Bob': 78})
_check('delete Eve → False', ok2, False)
# Out:
# ── Exercise 1: add_or_update / delete_student ──
#   ✔ APPROVED — add Alice
#   ✔ APPROVED — add Bob
#   ✔ APPROVED — update Alice
#   ✔ APPROVED — delete Bob → dict
#   ✔ APPROVED — delete Bob → True
#   ✔ APPROVED — delete Eve → dict
#   ✔ APPROVED — delete Eve → False

# %% [markdown]
# ---
# ## Exercise 2 - Word Frequency
#
# Count how many times each word appears in a string. Return a dictionary.
#
# Hint: .lower().split() to normalise, then count.
#
# | Input | Expected Output |
# |---|---|
# | 'the cat sat on the mat' | {'the':2,'cat':1,'sat':1,'on':1,'mat':1} |

# %%
def word_frequency(text):
    freq_text = text.lower().split()
    freq_dict = {}
    for i in freq_text:
        if i in freq_dict:
            freq_dict[i] += 1
        else:
            freq_dict[i] = 1

    return freq_dict

# %%
def _check(label, got, expected):
    if got == expected:
        print(f'  APPROVED - {label}')
    else:
        print(f'  FAILED   - {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n-- Exercise 2: word_frequency --')
_check('cat mat', word_frequency('the cat sat on the mat'),
       {'the':2,'cat':1,'sat':1,'on':1,'mat':1})
_check('one word', word_frequency('hello hello hello'), {'hello':3})
# Out:
# -- Exercise 2: word_frequency --
#   APPROVED - cat mat
#   APPROVED - one word

# %% [markdown]
# ---
# ## Mini-Project - Inventory System
#
# An inventory is stored as {item_name: {'price': float, 'quantity': int}}.
#
# Write three functions:
#
# inventory_add(inv, name, price, qty) -- add item or increase quantity if exists. Return updated inventory.
#
# inventory_total_value(inv) -- return total value (price * quantity) across all items, rounded to 2 decimals.
#
# inventory_low_stock(inv, threshold) -- return a sorted list of item names where quantity is <= threshold.

# %%
def inventory_add(inv, name, price, qty):
    if name in inv:
        inv[name]['quantity'] += qty
    else:
        inv[name] = {'price': price, 'quantity': qty}

    return inv


def inventory_total_value(inv):
    total_value = 0
    for name in inv:
        total_value += inv[name]['quantity'] * inv[name]['price']
    
    return round(total_value, 2)

def inventory_low_stock(inv, threshold):
    results = []
    for name in inv:
        if inv[name]['quantity'] <= threshold:
            results.append(name)

    return results

# %%
def _check(label, got, expected):
    if got == expected:
        print(f'  APPROVED - {label}')
    else:
        print(f'  FAILED   - {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n-- Mini-Project: inventory --')
inv = {}
inv = inventory_add(inv, 'apple', 0.5, 100)
inv = inventory_add(inv, 'banana', 0.3, 5)
inv = inventory_add(inv, 'apple', 0.5, 20)
_check('apple qty',    inv.get('apple',{}).get('quantity'), 120)
_check('total value',  inventory_total_value(inv), 61.5)
_check('low stock 10', inventory_low_stock(inv, 10), ['banana'])
# Out:
# -- Mini-Project: inventory --
#   APPROVED - apple qty
#   APPROVED - total value
#   APPROVED - low stock 10
