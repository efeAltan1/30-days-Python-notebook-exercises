# %% [markdown]
# # Day 10 — Loops + Week 2 Capstone
#
# **How to use this notebook:**
# - Read each exercise, fill in your solution (replace `pass`)
# - Run the test cell right after to see **APPROVED** or **FAILED**
# - The Capstone at the end ties together everything from Days 6–10
# - Do NOT modify the test cells

# %% [markdown]
# ---
# ## Exercise 1 — Manual Even Sum
#
# Using a **`for` loop only** (no `sum()`, no `filter()`), return the sum of all **even** numbers in the list.
#
# | Input | Expected Output |
# |---|---|
# | `[1,2,3,4,5,6]` | `12` |
# | `[10,15,20,25]` | `30` |
# | `[1,3,5]` | `0` |

# %%
def even_sum(numbers):
    even_total = 0
    for i in numbers:
        if i % 2 == 0:
            even_total += i
        
    return even_total

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 1: even_sum ──')
_check('[1,2,3,4,5,6]', even_sum([1,2,3,4,5,6]), 12)
_check('[10,15,20,25]', even_sum([10,15,20,25]),  30)
_check('[1,3,5]',       even_sum([1,3,5]),         0)
# Out:
# ── Exercise 1: even_sum ──
#   ✔ APPROVED — [1,2,3,4,5,6]
#   ✔ APPROVED — [10,15,20,25]
#   ✔ APPROVED — [1,3,5]

# %% [markdown]
# ---
# ## Exercise 2 — Multiplication Table
#
# Using **nested `for` loops**, return a 2D list (list of lists) where:
#
# `table[i][j] = (i+1) * (j+1)`
#
# | Input | Expected Output |
# |---|---|
# | `multiplication_table(2, 3)` | `[[1,2,3], [2,4,6]]` |
# | `multiplication_table(3, 3)` | `[[1,2,3], [2,4,6], [3,6,9]]` |

# %%
def multiplication_table(rows, cols):
    table = []
    for i in range(rows):
        row_list = []
        for j in range(cols):
            row_list.append((i+1) * (j+1))
        table.append(row_list) 
            
    
    return table

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 2: multiplication_table ──')
_check('2x3', multiplication_table(2,3), [[1,2,3],[2,4,6]])
_check('3x3', multiplication_table(3,3), [[1,2,3],[2,4,6],[3,6,9]])
# Out:
# ── Exercise 2: multiplication_table ──
#   ✔ APPROVED — 2x3
#   ✔ APPROVED — 3x3

# %% [markdown]
# ---
# ## ⭐ Week 2 Capstone — Contact Book
#
# This capstone ties together **tuples, sets, dictionaries, conditionals, and loops** from Days 6–10.
#
# Contacts are stored as:
# ```python
# {name: {'phone': str, 'email': str}}
# ```
#
# ---
# ### `contact_add(contacts, name, phone, email)`
# - If name already exists → return `(contacts, False)` unchanged
# - If new → add and return `(updated_contacts, True)`
#
# ### `contact_search(contacts, query)`
# - Case-insensitive partial match on name
# - Return a **sorted list** of matching names
#
# ### `contact_update(contacts, name, field, value)`
# - `field` is `'phone'` or `'email'`
# - Return `(updated_contacts, True)` if found, `(contacts, False)` if not
#
# ### `contact_delete(contacts, name)`
# - Return `(updated_contacts, True)` if found, `(contacts, False)` if not
#
# ### `contact_report(contacts)`
# - Return a dict with:
#   - `'total'`: number of contacts
#   - `'names_sorted'`: sorted list of all names
#   - `'email_domains'`: **set** of unique domains (e.g. `{'gmail.com', 'yahoo.com'}`)

# %%
def contact_add(contacts, name, phone, email):
    if name in contacts:
        return (contacts, False)
    else:
        #add contact and return the new contact list
        contacts[name] = {'phone': phone, 'email': email}

    return (contacts, True)


def contact_search(contacts, query):
    results = []
    for i in contacts:
        if query.lower() in i.lower():
            results.append(i)
    
    return sorted(results)

def contact_update(contacts, name, field, value):
    if name in contacts:
        contacts[name][field] = value
        return (contacts, True)
    else:
        return (contacts, False)

def contact_delete(contacts, name):
    if name in contacts:
        del contacts[name]
        return (contacts, True)
    else: 
        return (contacts, False)

def contact_report(contacts):
    return {
        
        'total' : len(contacts),
        'names_sorted' : sorted(contacts),
        'email_domains': {contacts[name]['email'].split('@')[1] for name in contacts}

    }

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Capstone: Contact Book ──')
c = {}
c, ok = contact_add(c, 'Alice', '555-1234', 'alice@gmail.com')
_check('add Alice → True',       ok, True)
c, ok = contact_add(c, 'Bob', '555-5678', 'bob@yahoo.com')
_check('add Bob → True',         ok, True)
c, ok = contact_add(c, 'Alice', '555-9999', 'x@x.com')
_check('add Alice again → False', ok, False)

_check('search ali', contact_search(c, 'ali'), ['Alice'])
_check('search b',   contact_search(c, 'b'),   ['Bob'])

c, ok = contact_update(c, 'Alice', 'phone', '555-0000')
_check('update Alice phone → True', ok, True)
_check('Alice phone updated',       c['Alice']['phone'], '555-0000')
_, ok2 = contact_update(c, 'Eve', 'phone', '000')
_check('update Eve → False',        ok2, False)

c2 = {k: dict(v) for k, v in c.items()}
c2, ok = contact_delete(c2, 'Bob')
_check('delete Bob → True',  ok,           True)
_check('Bob removed',        'Bob' in c2,  False)
_, ok2 = contact_delete(c2, 'Eve')
_check('delete Eve → False', ok2,          False)

report = contact_report(c)
_check('report total',        report.get('total'),         2)
_check('report names_sorted', report.get('names_sorted'),  ['Alice','Bob'])
_check('report domains',      report.get('email_domains'), {'gmail.com','yahoo.com'})
# Out:
# ── Capstone: Contact Book ──
#   ✔ APPROVED — add Alice → True
#   ✔ APPROVED — add Bob → True
#   ✔ APPROVED — add Alice again → False
#   ✔ APPROVED — search ali
#   ✔ APPROVED — search b
#   ✔ APPROVED — update Alice phone → True
#   ✔ APPROVED — Alice phone updated
#   ✔ APPROVED — update Eve → False
#   ✔ APPROVED — delete Bob → True
#   ✔ APPROVED — Bob removed
#   ✔ APPROVED — delete Eve → False
#   ✔ APPROVED — report total
#   ✔ APPROVED — report names_sorted
#   ✔ APPROVED — report domains
