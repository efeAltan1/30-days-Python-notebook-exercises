# %% [markdown]
# # Day 9 — Conditionals
#
# **How to use this notebook:**
# - Read each exercise, fill in your solution (replace `pass`)
# - Run the test cell right after to see **APPROVED** or **FAILED**
# - Do NOT modify the test cells
#
# **Key concept:** Conditionals control the **flow** of your program. Python uses `if`, `elif`, and `else` to branch based on conditions.

# %% [markdown]
# ---
# ## Exercise 1 — Grade Classifier
#
# Return the letter grade for a numeric score using `if/elif/else`.
#
# | Score range | Grade |
# |---|---|
# | 90–100 | `'A'` |
# | 80–89 | `'B'` |
# | 70–79 | `'C'` |
# | 60–69 | `'D'` |
# | below 60 | `'F'` |

# %%
def classify_grade(score):
    if 90 <= score <= 100:
        return 'A'
    elif 80 <= score <= 89:
        return 'B'
    elif 70 <= score <= 79:
        return 'C'
    elif 60 <= score <= 69:
        return 'D'
    elif score < 60:
        return 'F'

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 1: classify_grade ──')
_check('95 → A', classify_grade(95), 'A')
_check('83 → B', classify_grade(83), 'B')
_check('74 → C', classify_grade(74), 'C')
_check('61 → D', classify_grade(61), 'D')
_check('45 → F', classify_grade(45), 'F')
# Out:
# ── Exercise 1: classify_grade ──
#   ✔ APPROVED — 95 → A
#   ✔ APPROVED — 83 → B
#   ✔ APPROVED — 74 → C
#   ✔ APPROVED — 61 → D
#   ✔ APPROVED — 45 → F

# %% [markdown]
# ---
# ## Exercise 2 — Loan Eligibility
#
# Check three criteria **in order**. Return the first failing reason, or `'approved'` if all pass.
#
# | Check | Condition | Failure message |
# |---|---|---|
# | 1st | `age >= 18` | `'too young'` |
# | 2nd | `income >= 30000` | `'insufficient income'` |
# | 3rd | `credit_score >= 650` | `'low credit score'` |
# | All pass | — | `'approved'` |
#
# **Important:** Check them in order — stop and return the first failure.

# %%
def loan_eligible(age, income, credit_score):
    if age <= 18:
        return 'too young'
    elif income <= 30000:
        return 'insufficient income'
    elif credit_score <= 650:
        return 'low credit score'
    else:
        return 'approved'

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 2: loan_eligible ──')
_check('all pass',   loan_eligible(25,50000,700), 'approved')
_check('too young',  loan_eligible(16,50000,700), 'too young')
_check('low income', loan_eligible(25,20000,700), 'insufficient income')
_check('low credit', loan_eligible(25,50000,600), 'low credit score')
# Out:
# ── Exercise 2: loan_eligible ──
#   ✔ APPROVED — all pass
#   ✔ APPROVED — too young
#   ✔ APPROVED — low income
#   ✔ APPROVED — low credit

# %% [markdown]
# ---
# ## Mini-Project - Ticket Pricing System
#
# A cinema charges different prices based on age, membership, and day.
#
# Rules (apply in order):
# - If day == 'tuesday' -> flat price of 5.00 (ignores all other rules)
# - If age < 5 -> free (0.00)
# - Base price: 12.00
# - If age < 12 -> 50% discount
# - If age >= 65 -> 30% discount
# - If is_member -> additional 2.00 off
# - Minimum price is always 0.00
#
# Return price as a float rounded to 2 decimals.
#
# | Input | Expected |
# |---|---|
# | ticket_price(25, False, 'monday') | 12.0 |
# | ticket_price(8, False, 'monday') | 6.0 |
# | ticket_price(8, True, 'monday') | 4.0 |
# | ticket_price(70, True, 'monday') | 6.4 |
# | ticket_price(25, True, 'tuesday') | 5.0 |
# | ticket_price(3, False, 'monday') | 0.0 |

# %%
def ticket_price(age, is_member, day):
    price = 12.00
    if day == 'tuesday':
        price = 5.00
    if age < 5:
        price = 0.00
    elif age < 12:
        price *= 0.5
    elif age >= 65:
        price *= 0.7
    if day != 'tuesday' and is_member:
        price -= 2
    

    return round(price, 2)

# %%
def _check(label, got, expected):
    if got == expected:
        print(f'  APPROVED - {label}')
    else:
        print(f'  FAILED   - {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n-- Mini-Project: ticket_price --')
_check('adult no membership', ticket_price(25, False, 'monday'), 12.0)
_check('child no membership', ticket_price(8,  False, 'monday'),  6.0)
_check('child + membership',  ticket_price(8,  True,  'monday'),  4.0)
_check('senior + membership', ticket_price(70, True,  'monday'),  6.4)
_check('tuesday special',     ticket_price(25, True,  'tuesday'), 5.0)
_check('under 5 free',        ticket_price(3,  False, 'monday'),  0.0)
# Out:
# -- Mini-Project: ticket_price --
#   APPROVED - adult no membership
#   APPROVED - child no membership
#   APPROVED - child + membership
#   APPROVED - senior + membership
#   APPROVED - tuesday special
#   APPROVED - under 5 free
