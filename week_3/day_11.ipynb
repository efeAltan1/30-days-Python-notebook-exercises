# %% [markdown]
# # Day 11 — Functions
#
# **How to use this notebook:**
# - Read each exercise, fill in your solution (replace `pass`)
# - Run the test cell right after to see **APPROVED** or **FAILED**
# - Do NOT modify the test cells
#
# **Key concepts today:** `def`, parameters, return values, default parameters, `*args`, `**kwargs`

# %% [markdown]
# ---
# ## Exercise 1 — Factorial
#
# Write a function that returns the factorial of `n`.
#
# - `factorial(0)` = 1
# - `factorial(n)` = n × (n-1) × ... × 1
#
# ⚠️ You may use a loop or recursion — your choice.
#
# | Input | Expected Output |
# |---|---|
# | `factorial(0)` | `1` |
# | `factorial(1)` | `1` |
# | `factorial(5)` | `120` |
# | `factorial(7)` | `5040` |

# %%
def factorial(n):
    result = 1
    if n == 0:
        return 1
    for i in range(1, n+1):
        result *= i

    return result

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 1: factorial ──')
_check('factorial(0)', factorial(0), 1)
_check('factorial(1)', factorial(1), 1)
_check('factorial(5)', factorial(5), 120)
_check('factorial(7)', factorial(7), 5040)
# Out:
# ── Exercise 1: factorial ──
#   ✔ APPROVED — factorial(0)
#   ✔ APPROVED — factorial(1)
#   ✔ APPROVED — factorial(5)
#   ✔ APPROVED — factorial(7)

# %% [markdown]
# ---
# ## Exercise 2 — Is Prime?
#
# Write a function that returns `True` if a number is prime, `False` otherwise.
#
# A prime number is only divisible by 1 and itself.
#
# | Input | Expected Output |
# |---|---|
# | `is_prime(2)` | `True` |
# | `is_prime(7)` | `True` |
# | `is_prime(1)` | `False` |
# | `is_prime(9)` | `False` |
# | `is_prime(17)` | `True` |

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False

    return True

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 2: is_prime ──')
_check('is_prime(2)',  is_prime(2),  True)
_check('is_prime(7)',  is_prime(7),  True)
_check('is_prime(1)',  is_prime(1),  False)
_check('is_prime(9)',  is_prime(9),  False)
_check('is_prime(17)', is_prime(17), True)
# Out:
# ── Exercise 2: is_prime ──
#   ✔ APPROVED — is_prime(2)
#   ✔ APPROVED — is_prime(7)
#   ✔ APPROVED — is_prime(1)
#   ✔ APPROVED — is_prime(9)
#   ✔ APPROVED — is_prime(17)

# %% [markdown]
# ---
# ## Mini-Project — Statistics Calculator
#
# Write a function that takes a list of numbers and returns a full stats report.
#
# **Do NOT use the `statistics` module** — calculate everything manually using loops and math.
#
# Return a dict with:
# - `'count'`: number of items
# - `'sum'`: total
# - `'mean'`: average (rounded to 2 decimals)
# - `'min'`: smallest value
# - `'max'`: largest value
# - `'range'`: max - min

# %%
def stats_report(numbers):
    return{
        'count' : len(numbers),
        'sum': sum(numbers),
        'mean': round(sum(numbers) / len(numbers), 2),
        'min': min(numbers),
        'max': max(numbers),
        'range': numbers[-1] - numbers[0]


    }

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Mini-Project: stats_report ──')
_check('[2,4,6,8,10]', stats_report([2,4,6,8,10]),
       {'count':5,'sum':30,'mean':6.0,'min':2,'max':10,'range':8})
_check('[1,1,1]', stats_report([1,1,1]),
       {'count':3,'sum':3,'mean':1.0,'min':1,'max':1,'range':0})
# Out:
# ── Mini-Project: stats_report ──
#   ✔ APPROVED — [2,4,6,8,10]
#   ✔ APPROVED — [1,1,1]
