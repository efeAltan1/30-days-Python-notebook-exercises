# %% [markdown]
# # Day 13 — List Comprehension & Lambda Functions
#
# **How to use this notebook:**
# - Read each exercise, fill in your solution (replace `pass`)
# - Run the test cell right after to see **APPROVED** or **FAILED**
# - Do NOT modify the test cells
#
# **Key concepts today:**
# - List comprehension: `[expression for item in iterable if condition]`
# - Lambda: `lambda param: expression`

# %% [markdown]
# ---
# ## Exercise 1 — List Comprehension: Transform
#
# Using a **list comprehension**, return a new list where every number is squared.
#
# ⚠️ You must use list comprehension — no regular `for` loops.
#
# | Input | Expected Output |
# |---|---|
# | `[1,2,3,4,5]` | `[1,4,9,16,25]` |
# | `[0,3,6]` | `[0,9,36]` |

# %%
def square_all(numbers):
    return [i ** 2 for i in numbers]

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 1: square_all ──')
_check('[1,2,3,4,5]', square_all([1,2,3,4,5]), [1,4,9,16,25])
_check('[0,3,6]',     square_all([0,3,6]),     [0,9,36])
# Out:
# ── Exercise 1: square_all ──
#   ✔ APPROVED — [1,2,3,4,5]
#   ✔ APPROVED — [0,3,6]

# %% [markdown]
# ---
# ## Exercise 2 — Comprehension + Condition: Word Filter
#
# Using a **list comprehension**, return all words longer than `min_length` characters, converted to uppercase.
#
# | Input | Expected Output |
# |---|---|
# | `filter_words(['hi','hello','hey','world'], 3)` | `['HELLO','WORLD']` |
# | `filter_words(['a','bb','ccc','dddd'], 2)` | `['CCC','DDDD']` |

# %%
def filter_words(words, min_length):
    return [i.upper() for i in words if min_length < len(i)]

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 2: filter_words ──')
_check('words > 3 chars', filter_words(['hi','hello','hey','world'],3), ['HELLO','WORLD'])
_check('words > 2 chars', filter_words(['a','bb','ccc','dddd'],2),      ['CCC','DDDD'])
# Out:
# ── Exercise 2: filter_words ──
#   ✔ APPROVED — words > 3 chars
#   ✔ APPROVED — words > 2 chars

# %% [markdown]
# ---
# ## Mini-Project — Text Analyzer
#
# Analyze a block of text using **list comprehensions** and return a report dict.
#
# - `'word_count'`: total number of words
# - `'unique_words'`: number of unique words (case-insensitive)
# - `'long_words'`: list of words longer than 5 characters (lowercase, sorted, no duplicates)
# - `'avg_word_length'`: average word length rounded to 2 decimals
#
# **Hint:** Use `.split()`, `.lower()`, and comprehensions for all of these.

# %%
def text_analyzer(text):
    split_text = text.lower().split()
    return{

        'word_count': len(split_text),
        'unique_words': len(set(split_text)),
        'long_words': [i for i in sorted(set(split_text)) if len(i) > 5],
        'avg_word_length': round(sum(len(i) for i in split_text) / len(split_text), 2)

    }

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Mini-Project: text_analyzer ──')
text = 'Python is a powerful programming language Python is great'
result = text_analyzer(text)
_check('word_count',     result.get('word_count'),     9)
_check('unique_words',   result.get('unique_words'),   7)
_check('long_words',     result.get('long_words'),     ['language', 'powerful', 'programming', 'python'])
_check('avg_word_length',result.get('avg_word_length'), 5.44)
# Out:
# ── Mini-Project: text_analyzer ──
#   ✔ APPROVED — word_count
#   ✔ APPROVED — unique_words
#   ✔ APPROVED — long_words
#   ✔ APPROVED — avg_word_length
