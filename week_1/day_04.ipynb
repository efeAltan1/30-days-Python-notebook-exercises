# %% [markdown]
# # Day 4 — Strings
#
# **How to use this notebook:**
# - Read each exercise, fill in your solution (replace `pass`)
# - Run the test cell right after to see **APPROVED** or **FAILED**
# - Do NOT modify the test cells

# %% [markdown]
# ---
# ## Exercise 1 — String Analyzer
#
# Analyze a sentence and return a dictionary with the following keys:
#
# | Key | Description |
# |---|---|
# | `'upper'` | full uppercase version |
# | `'lower'` | full lowercase version |
# | `'title'` | title case version |
# | `'words'` | number of words |
# | `'chars'` | character count **excluding spaces** |
#
# **Hint:** Use `.upper()`, `.lower()`, `.title()`, `.split()`, `.replace()`

# %%
def analyze_string(sentence):
    pass

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 1: analyze_string ──')
_check('hello world',   analyze_string('hello world'),   {'upper':'HELLO WORLD','lower':'hello world','title':'Hello World','words':2,'chars':10})
_check('Python is fun', analyze_string('Python is fun'), {'upper':'PYTHON IS FUN','lower':'python is fun','title':'Python Is Fun','words':3,'chars':11})

# %% [markdown]
# ---
# ## Exercise 2 — Palindrome Checker
#
# A palindrome reads the same forwards and backwards (e.g. `'racecar'`).
#
# Return `True` if the text is a palindrome, `False` if not.
#
# ⚠️ **Ignore case and spaces.**
#
# **Hint:** Use `.replace()`, `.lower()`, and slicing `[::-1]`
#
# | Input | Expected Output |
# |---|---|
# | `'racecar'` | `True` |
# | `'hello'` | `False` |
# | `'A man a plan a canal Panama'` | `True` |

# %%
def is_palindrome(text):
    pass

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 2: is_palindrome ──')
_check('racecar',                       is_palindrome('racecar'),                       True)
_check('hello',                         is_palindrome('hello'),                         False)
_check('A man a plan a canal Panama',   is_palindrome('A man a plan a canal Panama'),   True)

# %% [markdown]
# ---
# ## Mini-Project — Mad Libs
#
# Fill in the blanks of a story template and return it as a string.
#
# **Template:**
# ```
# {name} woke up feeling very {adjective}.
#  They grabbed their {noun} and decided to {verb} all the way to {place}.
#  It was the most {adjective} day of their life.
# ```
#
# Note: `{adjective}` appears **twice** — use the same value both times.

# %%
def mad_libs(name, adjective, noun, verb, place):
    pass

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

expected = (
    'Alice woke up feeling very excited.\n'
    ' They grabbed their backpack and decided to run all the way to the mountains.\n'
    ' It was the most excited day of their life.'
)
print('\n── Mini-Project: mad_libs ──')
_check('mad_libs Alice', mad_libs('Alice','excited','backpack','run','the mountains'), expected)
if mad_libs('Alice','excited','backpack','run','the mountains') == expected:
    print('\n📖 Story preview:')
    print(mad_libs('Alice','excited','backpack','run','the mountains'))
