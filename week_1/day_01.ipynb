# %% [markdown]
# # Day 1 — Introduction: Data Types, `print()`, `type()`, Basic Math
#
# **How to use this notebook:**
# - Read each exercise description carefully
# - Fill in your solution in the code cell below it (replace `pass`)
# - Run the test cell right after to see **APPROVED** or **FAILED**
# - Do NOT modify the test cells

# %% [markdown]
# ---
# ## Exercise 1 — What Type Is It?
#
# Python has several built-in data types: `int`, `float`, `str`, `bool`, `list`, and more.
#
# Write a function that takes any value and returns the **name of its type as a plain string**.
#
# **Hint:** use `type()` and `.__name__`
#
# | Input | Expected Output |
# |---|---|
# | `42` | `'int'` |
# | `3.14` | `'float'` |
# | `'hello'` | `'str'` |
# | `True` | `'bool'` |
# | `[1,2,3]` | `'list'` |

# %%
def get_type(value):
    pass

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 1: get_type ──')
_check('get_type(42)',      get_type(42),      'int')
_check('get_type(3.14)',    get_type(3.14),    'float')
_check("get_type('hello')", get_type('hello'), 'str')
_check('get_type(True)',    get_type(True),    'bool')
_check('get_type([1,2])',   get_type([1,2]),   'list')

# %% [markdown]
# ---
# ## Exercise 2 — Formatted Bio
#
# Write a function that takes a name, age, and country and returns a formatted sentence.
#
# **Expected format:** `"My name is {name}. I am {age} years old. I live in {country}."`
#
# | Input | Expected Output |
# |---|---|
# | `bio('Alice', 25, 'Turkey')` | `'My name is Alice. I am 25 years old. I live in Turkey.'` |
# | `bio('Bob', 30, 'Germany')` | `'My name is Bob. I am 30 years old. I live in Germany.'` |

# %%
def bio(name, age, country):
    pass

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

print('\n── Exercise 2: bio ──')
_check('bio Alice', bio('Alice', 25, 'Turkey'), 'My name is Alice. I am 25 years old. I live in Turkey.')
_check('bio Bob',   bio('Bob', 30, 'Germany'),  'My name is Bob. I am 30 years old. I live in Germany.')

# %% [markdown]
# ---
# ## Mini-Project — Personal Info Card
#
# Build a function that returns a formatted info card as a **multi-line string**.
#
# **Expected output:**
# ```
# ==============================
# Name:     Alice
# Age:      25
# Country:  Turkey
# Language: Python
# ==============================
# ```
#
# **Hint:** use a triple-quoted string or `\n` to join lines.

# %%
def info_card(name, age, country, language):
    pass

# %%
# TEST CELL — do not modify
def _check(label, got, expected):
    if got == expected:
        print(f'  ✔ APPROVED — {label}')
    else:
        print(f'  ✘ FAILED   — {label}')
        print(f'             got:      {got!r}')
        print(f'             expected: {expected!r}')

expected_card = (
    '==============================\n'
    'Name:     Alice\n'
    'Age:      25\n'
    'Country:  Turkey\n'
    'Language: Python\n'
    '=============================='
)
print('\n── Mini-Project: info_card ──')
_check('info_card Alice', info_card('Alice', 25, 'Turkey', 'Python'), expected_card)
if info_card('Alice', 25, 'Turkey', 'Python') == expected_card:
    print('\n📋 Preview:')
    print(info_card('Alice', 25, 'Turkey', 'Python'))
